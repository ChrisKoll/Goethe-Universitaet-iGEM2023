# %%
import coolbox
from coolbox.api import *
from os.path import join

# %%
DATA = "../data"
TEST_RANGE = "chr1:1-200000"

# %%
genome = join(DATA, "vibpham_genome.fasta")
gft = join(DATA, "GCA_000196095.1_ASM19609v1_genomic.gtf") # needs tabix (linux package) to function

# %%
frame = XAxis() + GTF(gft)
frame.plot(TEST_RANGE)

# %%
brs = Browser(frame)

# %%
brs.show()
